# %%
import json

# %%
data = open("data.json",'r')
rec = data.read()
data.close()

records = json.loads(rec)

# %%
records
# Out:
# {'000': {'EXP': '00-00-00',
#   'MFD': '00-00-00',
#   'Name': 'Trial',
#   'Price': '000',
#   'Type': 'Delete'},
#  '001': {'EXP': '01-01-2022',
#   'MFD': '01-01-2020',
#   'Name': 'Item 01',
#   'Price': '400',
#   'Type': 'General'},
#  '002': {'EXP': '01-02-2022',
#   'MFD': '01-02-2020',
#   'Name': 'Item 02',
#   'Price': '600',
#   'Type': 'General'},
#  '003': {'EXP': '01-01-2022',
#   'MFD': '01-01-2020',
#   'Name': 'Item 03',
#   'Price': '1000',
#   'Type': 'Special'},
#  '004': {'EXP': '01-02-2022',
#   'MFD': '01-02-2020',
#   'Name': 'Item 04',
#   'Price': '1200',
#   'Type': 'Special'},
#  '005': {'EXP': '01-03-2022',
#   'MFD': '01-03-2020',
#   'Name': 'Item 05',
#   'Price': '400',
#   'Type': 'General'},
#  '006': {'EXP': '01-04-2022',
#   'MFD': '01-04-2020',
#   'Name': 'Item 06',
#   'Price': '600',
#   'Type': 'General'},
#  '007': {'EXP': '01-03-2022',
#   'MFD': '01-03-2020',
#   'Name': 'Item 07',
#   'Price': '1000',
#   'Type': 'Special'},
# ...

# %%
prod_id  = str(input("Enter the Product Id: "))

q = int(input("Enter the quantity: "))

print("Product: ", records[prod_id]['Name'])
print("Type: ", records[prod_id]['Type'])
print("MFD: ", records[prod_id]['MFD'])
print("EXP: ", records[prod_id]['EXP'])
print("Billing Amount: ", int(records[prod_id]['Price']) * q)
# Out:
# Enter the Product Id: 001
# Enter the quantity: 21
# Product:  Item 01
# Type:  General
# MFD:  01-01-2020
# EXP:  01-01-2022
# Billing Amount:  8400

# %%
RemainingProduct = --q
print(RemainingProduct)
# Out:
# 21

# %%
js = json.dumps(records)

data = open("data.json",'w')
data.write(js)
data.close()

# %%
{'Product' : prod_id, 'Type': records[prod_id]['Type'], 'Quantity' : q, 'Amount': int(records[prod_id]['Price']) * q, 'MFD': records[prod_id]['MFD'], 'EXP': records[prod_id]['EXP'] }
# Out:
# {'Amount': 8400,
#  'EXP': '01-01-2022',
#  'MFD': '01-01-2020',
#  'Product': '001',
#  'Quantity': 21,
#  'Type': 'General'}

# %%
data = open("record.json",'w')
data.write(js)
data.close()

# %%
prod_ID = str(input("Enter product id:"))
Name = str(input("Enter name:"))
Price = int(input("Enter price:"))
Type = str(input("Enter type:"))
MFD = str(input("Enter MFD:"))
EXP = str(input("Enter EXP:"))


records[prod_ID] = {'Name': Name, 'Type': Type, 'Price': Price, 'MFD': MFD, 'EXP' : EXP}

js = json.dumps(records)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:031
# Enter name:Item 31
# Enter price:400
# Enter type:General
# Enter MFD:01-04-2021
# Enter EXP:01-04-2023

# %%
records
# Out:
# {'000': {'EXP': '00-00-00',
#   'MFD': '00-00-00',
#   'Name': 'Trial',
#   'Price': '000',
#   'Type': 'Delete'},
#  '001': {'EXP': '01-01-2022',
#   'MFD': '01-01-2020',
#   'Name': 'Item 01',
#   'Price': '400',
#   'Type': 'General'},
#  '002': {'EXP': '01-02-2022',
#   'MFD': '01-02-2020',
#   'Name': 'Item 02',
#   'Price': '600',
#   'Type': 'General'},
#  '003': {'EXP': '01-01-2022',
#   'MFD': '01-01-2020',
#   'Name': 'Item 03',
#   'Price': '1000',
#   'Type': 'Special'},
#  '004': {'EXP': '01-02-2022',
#   'MFD': '01-02-2020',
#   'Name': 'Item 04',
#   'Price': '1200',
#   'Type': 'Special'},
#  '005': {'EXP': '01-03-2022',
#   'MFD': '01-03-2020',
#   'Name': 'Item 05',
#   'Price': '400',
#   'Type': 'General'},
#  '006': {'EXP': '01-04-2022',
#   'MFD': '01-04-2020',
#   'Name': 'Item 06',
#   'Price': '600',
#   'Type': 'General'},
#  '007': {'EXP': '01-03-2022',
#   'MFD': '01-03-2020',
#   'Name': 'Item 07',
#   'Price': '1000',
#   'Type': 'Special'},
# ...

# %%
del records['000']

# %%
records
# Out:
# {'001': {'EXP': '01-01-2022',
#   'MFD': '01-01-2020',
#   'Name': 'Item 01',
#   'Price': '400',
#   'Type': 'General'},
#  '002': {'EXP': '01-02-2022',
#   'MFD': '01-02-2020',
#   'Name': 'Item 02',
#   'Price': '600',
#   'Type': 'General'},
#  '003': {'EXP': '01-01-2022',
#   'MFD': '01-01-2020',
#   'Name': 'Item 03',
#   'Price': '1000',
#   'Type': 'Special'},
#  '004': {'EXP': '01-02-2022',
#   'MFD': '01-02-2020',
#   'Name': 'Item 04',
#   'Price': '1200',
#   'Type': 'Special'},
#  '005': {'EXP': '01-03-2022',
#   'MFD': '01-03-2020',
#   'Name': 'Item 05',
#   'Price': '400',
#   'Type': 'General'},
#  '006': {'EXP': '01-04-2022',
#   'MFD': '01-04-2020',
#   'Name': 'Item 06',
#   'Price': '600',
#   'Type': 'General'},
#  '007': {'EXP': '01-03-2022',
#   'MFD': '01-03-2020',
#   'Name': 'Item 07',
#   'Price': '1000',
#   'Type': 'Special'},
#  '008': {'EXP': '01-04-2022',
#   'MFD': '01-04-2020',
#   'Name': 'Item 08',
#   'Price': '1200',
#   'Type': 'Special'},
# ...
